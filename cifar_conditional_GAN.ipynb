# %% [markdown]
# <a href="https://colab.research.google.com/github/srivatsalnarayan/Gan_cifar/blob/main/cifar_conditional_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import zeros
from numpy import ones
from numpy.random import randn
from numpy.random import randint
from keras.datasets.cifar10 import load_data
from keras.optimizers import Adam
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Dropout
from keras.layers import Embedding
from keras.layers import Concatenate

from matplotlib import pyplot as plt

# %%
#Load data and plot to get a quick understanding
#CIFAR10 classes are: airplane, automobile, bird, cat, deer, dog, frog, horse,
# ship, truck

(trainX, trainy), (testX, testy) = load_data()

# plot 25 images
for i in range(25):
	plt.subplot(5, 5, 1 + i)
	plt.axis('off')
	plt.imshow(trainX[i])
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step

# %%
#############################################################################
#Define generator, discriminator, gan and other helper functions
#We will use functional way of defining model as we have multiple inputs;
#both images and corresponding labels.
########################################################################

# %%
# define the standalone discriminator model
#Given an input image, the Discriminator outputs the likelihood of the image being real.
#Binary classification - true or false (1 or 0). So using sigmoid activation.

# %%
#Unlike regular GAN here we are also providing number of classes as input.
#Input to the model will be both images and labels.
def define_discriminator(in_shape=(32,32,3), n_classes=10):

    # label input
	in_label = Input(shape=(1,))  #Shape 1
	# embedding for categorical input
    #each label (total 10 classes for cifar), will be represented by a vector of size 50.
    #This vector of size 50 will be learnt by the discriminator
	li = Embedding(n_classes, 50)(in_label) #Shape 1,50
	# scale up to image dimensions with linear activation
	n_nodes = in_shape[0] * in_shape[1]  #32x32 = 1024.
	li = Dense(n_nodes)(li)  #Shape = 1, 1024
	# reshape to additional channel
	li = Reshape((in_shape[0], in_shape[1], 1))(li)  #32x32x1


	# image input
	in_image = Input(shape=in_shape) #32x32x3
	# concat label as a channel
	merge = Concatenate()([in_image, li]) #32x32x4 (4 channels, 3 for image and the other for labels)

	# downsample: This part is same as unconditional GAN upto the output layer.
    #We will combine input label with input image and supply as inputs to the model.
	fe = Conv2D(128, (3,3), strides=(2,2), padding='same')(merge) #16x16x128
	fe = LeakyReLU(alpha=0.2)(fe)
	# downsample
	fe = Conv2D(128, (3,3), strides=(2,2), padding='same')(fe) #8x8x128
	fe = LeakyReLU(alpha=0.2)(fe)
	# flatten feature maps
	fe = Flatten()(fe)  #8192  (8*8*128=8192)
	# dropout
	fe = Dropout(0.4)(fe)
	# output
	out_layer = Dense(1, activation='sigmoid')(fe)  #Shape=1

	# define model
    ##Combine input label with input image and supply as inputs to the model.
	model = Model([in_image, in_label], out_layer)
	# compile model
	opt = Adam(lr=0.0002, beta_1=0.5)
	model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
	return model

test_discr = define_discriminator()
print(test_discr.summary())


# define the standalone generator model
#latent vector and label as inputs
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1)]          0           []
#
#  embedding (Embedding)          (None, 1, 50)        500         ['input_1[0][0]']
#
#  dense (Dense)                  (None, 1, 1024)      52224       ['embedding[0][0]']
#
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  reshape (Reshape)              (None, 32, 32, 1)    0           ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 32, 32, 4)    0           ['input_2[0][0]',
#                                                                   'reshape[0][0]']
#
#  conv2d (Conv2D)                (None, 16, 16, 128)  4736        ['concatenate[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 16, 16, 128)  0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 8, 8, 128)    147584      ['leaky_re_lu[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 8, 8, 128)    0           ['conv2d_1[0][0]']
#
#  flatten (Flatten)              (None, 8192)         0           ['leaky_re_lu_1[0][0]']
#
#  dropout (Dropout)              (None, 8192)         0           ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 1)            8193        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 213,237
# Trainable params: 213,237
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
def define_generator(latent_dim, n_classes=10):

	# label input
	in_label = Input(shape=(1,))  #Input of dimension 1
	# embedding for categorical input
    #each label (total 10 classes for cifar), will be represented by a vector of size 50.
	li = Embedding(n_classes, 50)(in_label) #Shape 1,50

	# linear multiplication
	n_nodes = 8 * 8  # To match the dimensions for concatenation later in this step.
	li = Dense(n_nodes)(li) #1,64
	# reshape to additional channel
	li = Reshape((8, 8, 1))(li)


	# image generator input
	in_lat = Input(shape=(latent_dim,))  #Input of dimension 100

	# foundation for 8x8 image
    # We will reshape input latent vector into 8x8 image as a starting point.
    #So n_nodes for the Dense layer can be 128x8x8 so when we reshape the output
    #it would be 8x8x128 and that can be slowly upscaled to 32x32 image for output.
    #Note that this part is same as unconditional GAN until the output layer.
    #While defining model inputs we will combine input label and the latent input.
	n_nodes = 128 * 8 * 8
	gen = Dense(n_nodes)(in_lat)  #shape=8192
	gen = LeakyReLU(alpha=0.2)(gen)
	gen = Reshape((8, 8, 128))(gen) #Shape=8x8x128
	# merge image gen and label input
	merge = Concatenate()([gen, li])  #Shape=8x8x129 (Extra channel corresponds to the label)
	# upsample to 16x16
	gen = Conv2DTranspose(128, (4,4), strides=(2,2), padding='same')(merge) #16x16x128
	gen = LeakyReLU(alpha=0.2)(gen)
	# upsample to 32x32
	gen = Conv2DTranspose(128, (4,4), strides=(2,2), padding='same')(gen) #32x32x128
	gen = LeakyReLU(alpha=0.2)(gen)
	# output
	out_layer = Conv2D(3, (8,8), activation='tanh', padding='same')(gen) #32x32x3
	# define model
	model = Model([in_lat, in_label], out_layer)
	return model   #Model not compiled as it is not directly trained like the discriminator.

test_gen = define_generator(100, n_classes=10)
print(test_gen.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 100)]        0           []
#
#  input_3 (InputLayer)           [(None, 1)]          0           []
#
#  dense_3 (Dense)                (None, 8192)         827392      ['input_4[0][0]']
#
#  embedding_1 (Embedding)        (None, 1, 50)        500         ['input_3[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 8192)         0           ['dense_3[0][0]']
#
#  dense_2 (Dense)                (None, 1, 64)        3264        ['embedding_1[0][0]']
#
#  reshape_2 (Reshape)            (None, 8, 8, 128)    0           ['leaky_re_lu_2[0][0]']
#
#  reshape_1 (Reshape)            (None, 8, 8, 1)      0           ['dense_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 129)    0           ['reshape_2[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 128)  264320     ['concatenate_1[0][0]']
#  ose)
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 16, 16, 128)  0           ['conv2d_transpose[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 128)  262272     ['leaky_re_lu_3[0][0]']
#  spose)
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 32, 32, 128)  0           ['conv2d_transpose_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 3)    24579       ['leaky_re_lu_4[0][0]']
#
# ==================================================================================================
# Total params: 1,382,327
# Trainable params: 1,382,327
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# #Generator is trained via GAN combined model.
# define the combined generator and discriminator model, for updating the generator
#Discriminator is trained separately so here only generator will be trained by keeping
#the discriminator constant.
def define_gan(g_model, d_model):
	d_model.trainable = False  #Discriminator is trained separately. So set to not trainable.

    ## connect generator and discriminator...
	# first, get noise and label inputs from generator model
	gen_noise, gen_label = g_model.input  #Latent vector size and label size
	# get image output from the generator model
	gen_output = g_model.output  #32x32x3

	# generator image output and corresponding input label are inputs to discriminator
	gan_output = d_model([gen_output, gen_label])
	# define gan model as taking noise and label and outputting a classification
	model = Model([gen_noise, gen_label], gan_output)
	# compile model
	opt = Adam(lr=0.0002, beta_1=0.5)
	model.compile(loss='binary_crossentropy', optimizer=opt)
	return model

# %%
# load cifar images
def load_real_samples():
	# load dataset
	(trainX, trainy), (_, _) = load_data()   #cifar
	# convert to floats and scale
	X = trainX.astype('float32')
	# scale from [0,255] to [-1,1]
	X = (X - 127.5) / 127.5   #Generator uses tanh activation so rescale
                            #original images to -1 to 1 to match the output of generator.
	return [X, trainy]

# %%
# # select real samples
# pick a batch of random real samples to train the GAN
#In fact, we will train the GAN on a half batch of real images and another
#half batch of fake images.
#For each real image we assign a label 1 and for fake we assign label 0.
def generate_real_samples(dataset, n_samples):
	# split into images and labels
	images, labels = dataset
	# choose random instances
	ix = randint(0, images.shape[0], n_samples)
	# select images and labels
	X, labels = images[ix], labels[ix]
	# generate class labels and assign to y (don't confuse this with the above labels that correspond to cifar labels)
	y = ones((n_samples, 1))  #Label=1 indicating they are real
	return [X, labels], y

# %%
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples, n_classes=10):
	# generate points in the latent space
	x_input = randn(latent_dim * n_samples)
	# reshape into a batch of inputs for the network
	z_input = x_input.reshape(n_samples, latent_dim)
	# generate labels
	labels = randint(0, n_classes, n_samples)
	return [z_input, labels]

# use the generator to generate n fake examples, with class labels
#Supply the generator, latent_dim and number of samples as input.
#Use the above latent point generator to generate latent points.
def generate_fake_samples(generator, latent_dim, n_samples):
	# generate points in latent space
	z_input, labels_input = generate_latent_points(latent_dim, n_samples)
	# predict outputs
	images = generator.predict([z_input, labels_input])
	# create class labels
	y = zeros((n_samples, 1))  #Label=0 indicating they are fake
	return [images, labels_input], y

# %%
# train the generator and discriminator
#We loop through a number of epochs to train our Discriminator by first selecting
#a random batch of images from our true/real dataset.
#Then, generating a set of images using the generator.
#Feed both set of images into the Discriminator.
#Finally, set the loss parameters for both the real and fake images, as well as the combined loss.
def train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=100, n_batch=128):
	bat_per_epo = int(dataset[0].shape[0] / n_batch)
	half_batch = int(n_batch / 2)  #the discriminator model is updated for a half batch of real samples
                            #and a half batch of fake samples, combined a single batch.
	# manually enumerate epochs
	for i in range(n_epochs):
		# enumerate batches over the training set
		for j in range(bat_per_epo):

             # Train the discriminator on real and fake images, separately (half batch each)
        #Research showed that separate training is more effective.
			# get randomly selected 'real' samples
            # get randomly selected 'real' samples
			[X_real, labels_real], y_real = generate_real_samples(dataset, half_batch)

            # update discriminator model weights
            ##train_on_batch allows you to update weights based on a collection
            #of samples you provide
			d_loss_real, _ = d_model.train_on_batch([X_real, labels_real], y_real)

			# generate 'fake' examples
			[X_fake, labels], y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
			# update discriminator model weights
			d_loss_fake, _ = d_model.train_on_batch([X_fake, labels], y_fake)

            #d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) #Average loss if you want to report single..

			# prepare points in latent space as input for the generator
			[z_input, labels_input] = generate_latent_points(latent_dim, n_batch)

            # The generator wants the discriminator to label the generated samples
        # as valid (ones)
        #This is where the generator is trying to trick discriminator into believing
        #the generated image is true (hence value of 1 for y)
			# create inverted labels for the fake samples
			y_gan = ones((n_batch, 1))
             # Generator is part of combined model where it got directly linked with the discriminator
        # Train the generator with latent_dim as x and 1 as y.
        # Again, 1 as the output as it is adversarial and if generator did a great
        #job of folling the discriminator then the output would be 1 (true)
			# update the generator via the discriminator's error
			g_loss = gan_model.train_on_batch([z_input, labels_input], y_gan)
			# Print losses on this batch
			print('Epoch>%d, Batch%d/%d, d1=%.3f, d2=%.3f g=%.3f' %
				(i+1, j+1, bat_per_epo, d_loss_real, d_loss_fake, g_loss))
	# save the generator model
	g_model.save('cifar_conditional_generator_25epochs.h5')

# %%
#Train the GAN

# size of the latent space
latent_dim = 100
# create the discriminator
d_model = define_discriminator()
# create the generator
g_model = define_generator(latent_dim)
# create the gan
gan_model = define_gan(g_model, d_model)
# load image data
dataset = load_real_samples()
# train model
train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=2)
# Out:
# 2/2 [==============================] - 2s 716ms/step
# Epoch>1, Batch1/390, d1=0.710, d2=0.698 g=0.689
# 2/2 [==============================] - 1s 609ms/step
# Epoch>1, Batch2/390, d1=0.631, d2=0.707 g=0.680
# 2/2 [==============================] - 1s 687ms/step
# Epoch>1, Batch3/390, d1=0.568, d2=0.724 g=0.665
# 2/2 [==============================] - 1s 675ms/step
# Epoch>1, Batch4/390, d1=0.526, d2=0.750 g=0.644
# 2/2 [==============================] - 1s 689ms/step
# Epoch>1, Batch5/390, d1=0.458, d2=0.784 g=0.618
# 2/2 [==============================] - 1s 693ms/step
# Epoch>1, Batch6/390, d1=0.427, d2=0.826 g=0.600
# 2/2 [==============================] - 1s 674ms/step
# Epoch>1, Batch7/390, d1=0.408, d2=0.848 g=0.594
# 2/2 [==============================] - 1s 572ms/step
# Epoch>1, Batch8/390, d1=0.372, d2=0.842 g=0.631
# 2/2 [==============================] - 1s 546ms/step
# Epoch>1, Batch9/390, d1=0.330, d2=0.751 g=0.727
# 2/2 [==============================] - 1s 721ms/step
# Epoch>1, Batch10/390, d1=0.374, d2=0.651 g=0.842
# 2/2 [==============================] - 1s 685ms/step
# Epoch>1, Batch11/390, d1=0.316, d2=0.582 g=0.916
# 2/2 [==============================] - 1s 672ms/step
# Epoch>1, Batch12/390, d1=0.405, d2=0.577 g=0.879
# 2/2 [==============================] - 1s 706ms/step
# Epoch>1, Batch13/390, d1=0.369, d2=0.613 g=0.815
# 2/2 [==============================] - 1s 418ms/step
# Epoch>1, Batch14/390, d1=0.281, d2=0.661 g=0.759
# 2/2 [==============================] - 1s 377ms/step
# Epoch>1, Batch15/390, d1=0.260, d2=0.712 g=0.711
# 2/2 [==============================] - 1s 379ms/step
# Epoch>1, Batch16/390, d1=0.330, d2=0.800 g=0.652
# 2/2 [==============================] - 1s 377ms/step
# Epoch>1, Batch17/390, d1=0.238, d2=0.975 g=0.558
# 2/2 [==============================] - 1s 650ms/step
# Epoch>1, Batch18/390, d1=0.251, d2=1.286 g=0.436
# 2/2 [==============================] - 1s 618ms/step
# Epoch>1, Batch19/390, d1=0.299, d2=1.569 g=0.366
# 2/2 [==============================] - 1s 592ms/step
# Epoch>1, Batch20/390, d1=0.290, d2=1.650 g=0.372
# 2/2 [==============================] - 1s 395ms/step
# Epoch>1, Batch21/390, d1=0.327, d2=1.427 g=0.490
# 2/2 [==============================] - 1s 376ms/step
# Epoch>1, Batch22/390, d1=0.327, d2=1.067 g=0.722
# 2/2 [==============================] - 1s 402ms/step
# Epoch>1, Batch23/390, d1=0.361, d2=0.679 g=1.057
# 2/2 [==============================] - 1s 393ms/step
# Epoch>1, Batch24/390, d1=0.395, d2=0.426 g=1.428
# 2/2 [==============================] - 1s 388ms/step
# Epoch>1, Batch25/390, d1=0.416, d2=0.335 g=1.540
# 2/2 [==============================] - 1s 385ms/step
# Epoch>1, Batch26/390, d1=0.389, d2=0.353 g=1.416
# 2/2 [==============================] - 1s 411ms/step
# Epoch>1, Batch27/390, d1=0.339, d2=0.423 g=1.198
# 2/2 [==============================] - 1s 385ms/step
# Epoch>1, Batch28/390, d1=0.336, d2=0.502 g=1.019
# 2/2 [==============================] - 1s 379ms/step
# Epoch>1, Batch29/390, d1=0.342, d2=0.565 g=0.887
# 2/2 [==============================] - 1s 374ms/step
# Epoch>1, Batch30/390, d1=0.335, d2=0.645 g=0.788
# 2/2 [==============================] - 1s 390ms/step
# Epoch>1, Batch31/390, d1=0.319, d2=0.763 g=0.678
# 2/2 [==============================] - 1s 375ms/step
# Epoch>1, Batch32/390, d1=0.289, d2=0.955 g=0.549
# 2/2 [==============================] - 1s 383ms/step
# Epoch>1, Batch33/390, d1=0.307, d2=1.243 g=0.424
# 2/2 [==============================] - 1s 374ms/step
# Epoch>1, Batch34/390, d1=0.217, d2=1.521 g=0.351
# 2/2 [==============================] - 1s 384ms/step
# Epoch>1, Batch35/390, d1=0.190, d2=1.597 g=0.333
# 2/2 [==============================] - 1s 372ms/step
# Epoch>1, Batch36/390, d1=0.246, d2=1.534 g=0.373
# 2/2 [==============================] - 1s 388ms/step
# Epoch>1, Batch37/390, d1=0.308, d2=1.330 g=0.471
# 2/2 [==============================] - 1s 384ms/step
# Epoch>1, Batch38/390, d1=0.369, d2=1.035 g=0.653
# 2/2 [==============================] - 1s 377ms/step
# Epoch>1, Batch39/390, d1=0.392, d2=0.731 g=0.959
# 2/2 [==============================] - 1s 403ms/step
# Epoch>1, Batch40/390, d1=0.451, d2=0.494 g=1.259
# 2/2 [==============================] - 1s 377ms/step
# Epoch>1, Batch41/390, d1=0.479, d2=0.398 g=1.389
# 2/2 [==============================] - 1s 392ms/step
# Epoch>1, Batch42/390, d1=0.499, d2=0.405 g=1.314
# 2/2 [==============================] - 1s 384ms/step
# Epoch>1, Batch43/390, d1=0.435, d2=0.479 g=1.110
# 2/2 [==============================] - 1s 377ms/step
# Epoch>1, Batch44/390, d1=0.546, d2=0.621 g=0.872
# 2/2 [==============================] - 1s 385ms/step
# Epoch>1, Batch45/390, d1=0.559, d2=0.809 g=0.676
# 2/2 [==============================] - 1s 394ms/step
# Epoch>1, Batch46/390, d1=0.490, d2=0.958 g=0.589
# 2/2 [==============================] - 1s 377ms/step
# Epoch>1, Batch47/390, d1=0.559, d2=1.010 g=0.563
# 2/2 [==============================] - 1s 417ms/step
# Epoch>1, Batch48/390, d1=0.489, d2=0.958 g=0.622
# 2/2 [==============================] - 1s 401ms/step
# Epoch>1, Batch49/390, d1=0.378, d2=0.827 g=0.749
# 2/2 [==============================] - 1s 390ms/step
# Epoch>1, Batch50/390, d1=0.308, d2=0.679 g=0.898
# 2/2 [==============================] - 1s 376ms/step
# Epoch>1, Batch51/390, d1=0.392, d2=0.588 g=1.064
# 2/2 [==============================] - 1s 407ms/step
# Epoch>1, Batch52/390, d1=0.350, d2=0.564 g=1.121
# 2/2 [==============================] - 1s 382ms/step
# Epoch>1, Batch53/390, d1=0.316, d2=0.619 g=1.102
# 2/2 [==============================] - 1s 454ms/step
# Epoch>1, Batch54/390, d1=0.329, d2=0.662 g=1.086
# 2/2 [==============================] - 1s 401ms/step
# Epoch>1, Batch55/390, d1=0.408, d2=0.675 g=1.085
# 2/2 [==============================] - 1s 385ms/step
# Epoch>1, Batch56/390, d1=0.358, d2=0.686 g=1.021
# 2/2 [==============================] - 1s 376ms/step
# Epoch>1, Batch57/390, d1=0.368, d2=0.690 g=0.954
# 2/2 [==============================] - 1s 388ms/step
# Epoch>1, Batch58/390, d1=0.519, d2=0.672 g=0.904
# 2/2 [==============================] - 1s 385ms/step
# Epoch>1, Batch59/390, d1=0.549, d2=0.645 g=0.911
# 2/2 [==============================] - 1s 386ms/step
# Epoch>1, Batch60/390, d1=0.589, d2=0.615 g=0.937
# 2/2 [==============================] - 1s 398ms/step
# Epoch>1, Batch61/390, d1=0.387, d2=0.587 g=0.957
# 2/2 [==============================] - 1s 521ms/step
# Epoch>1, Batch62/390, d1=0.386, d2=0.575 g=0.972
# 2/2 [==============================] - 1s 618ms/step
# Epoch>1, Batch63/390, d1=0.332, d2=0.573 g=0.974
# 2/2 [==============================] - 1s 708ms/step
# Epoch>1, Batch64/390, d1=0.372, d2=0.602 g=0.903
# 2/2 [==============================] - 1s 688ms/step
# Epoch>1, Batch65/390, d1=0.251, d2=0.699 g=0.820
# 2/2 [==============================] - 1s 685ms/step
# Epoch>1, Batch66/390, d1=0.371, d2=0.828 g=0.688
# 2/2 [==============================] - 1s 409ms/step
# Epoch>1, Batch67/390, d1=0.303, d2=0.965 g=0.601
# 2/2 [==============================] - 1s 398ms/step
# Epoch>1, Batch68/390, d1=0.274, d2=1.033 g=0.584
# 2/2 [==============================] - 1s 368ms/step
# Epoch>1, Batch69/390, d1=0.311, d2=1.000 g=0.652
# 2/2 [==============================] - 1s 392ms/step
# Epoch>1, Batch70/390, d1=0.326, d2=0.869 g=0.762
# 2/2 [==============================] - 1s 372ms/step
# Epoch>1, Batch71/390, d1=0.344, d2=0.768 g=0.870
# 2/2 [==============================] - 1s 475ms/step
# Epoch>1, Batch72/390, d1=0.485, d2=0.767 g=0.821
# 2/2 [==============================] - 1s 708ms/step
# Epoch>1, Batch73/390, d1=0.572, d2=0.843 g=0.744
# 2/2 [==============================] - 1s 661ms/step
# Epoch>1, Batch74/390, d1=0.477, d2=0.898 g=0.701
# 2/2 [==============================] - 1s 405ms/step
# Epoch>1, Batch75/390, d1=0.668, d2=0.847 g=0.701
# 2/2 [==============================] - 1s 381ms/step
# Epoch>1, Batch76/390, d1=0.573, d2=0.719 g=0.809
# 2/2 [==============================] - 1s 385ms/step
# Epoch>1, Batch77/390, d1=0.507, d2=0.590 g=0.978
# 2/2 [==============================] - 1s 380ms/step
# Epoch>1, Batch78/390, d1=0.546, d2=0.487 g=1.118
# 2/2 [==============================] - 1s 407ms/step
# Epoch>1, Batch79/390, d1=0.387, d2=0.426 g=1.223
# 2/2 [==============================] - 1s 401ms/step
# Epoch>1, Batch80/390, d1=0.450, d2=0.429 g=1.187
# 2/2 [==============================] - 1s 405ms/step
# Epoch>1, Batch81/390, d1=0.306, d2=0.448 g=1.119
# 2/2 [==============================] - 1s 399ms/step
# Epoch>1, Batch82/390, d1=0.304, d2=0.494 g=1.040
# 2/2 [==============================] - 1s 381ms/step
# Epoch>1, Batch83/390, d1=0.291, d2=0.529 g=1.007
# 2/2 [==============================] - 1s 377ms/step
# Epoch>1, Batch84/390, d1=0.273, d2=0.530 g=1.025
# 2/2 [==============================] - 1s 387ms/step
# Epoch>1, Batch85/390, d1=0.231, d2=0.482 g=1.122
# 2/2 [==============================] - 1s 385ms/step
# Epoch>1, Batch86/390, d1=0.228, d2=0.447 g=1.230
# 2/2 [==============================] - 1s 563ms/step
# Epoch>1, Batch87/390, d1=0.229, d2=0.439 g=1.246
# 2/2 [==============================] - 1s 703ms/step
# Epoch>1, Batch88/390, d1=0.207, d2=0.466 g=1.221
# 2/2 [==============================] - 1s 387ms/step
# Epoch>1, Batch89/390, d1=0.204, d2=0.509 g=1.198
# 2/2 [==============================] - 1s 377ms/step
# Epoch>1, Batch90/390, d1=0.197, d2=0.522 g=1.242
# 2/2 [==============================] - 1s 416ms/step
# Epoch>1, Batch91/390, d1=0.248, d2=0.482 g=1.330
# 2/2 [==============================] - 1s 646ms/step
# Epoch>1, Batch92/390, d1=0.335, d2=0.473 g=1.322
# 2/2 [==============================] - 1s 391ms/step
# Epoch>1, Batch93/390, d1=0.362, d2=0.520 g=1.129
# 2/2 [==============================] - 1s 401ms/step
# Epoch>1, Batch94/390, d1=0.365, d2=0.663 g=0.871
# 2/2 [==============================] - 1s 374ms/step
# Epoch>1, Batch95/390, d1=0.418, d2=0.768 g=0.729
# 2/2 [==============================] - 1s 651ms/step
# Epoch>1, Batch96/390, d1=0.362, d2=0.878 g=0.653
# 2/2 [==============================] - 1s 369ms/step
# Epoch>1, Batch97/390, d1=0.300, d2=0.931 g=0.622
# 2/2 [==============================] - 1s 402ms/step
# Epoch>1, Batch98/390, d1=0.279, d2=0.931 g=0.624
# 2/2 [==============================] - 1s 376ms/step
# Epoch>1, Batch99/390, d1=0.240, d2=0.951 g=0.666
# 2/2 [==============================] - 1s 401ms/step
# Epoch>1, Batch100/390, d1=0.318, d2=0.887 g=0.737
# 2/2 [==============================] - 1s 395ms/step
# Epoch>1, Batch101/390, d1=0.198, d2=0.841 g=0.852
# 2/2 [==============================] - 1s 390ms/step
# Epoch>1, Batch102/390, d1=0.214, d2=0.730 g=1.047
# 2/2 [==============================] - 1s 408ms/step
# Epoch>1, Batch103/390, d1=0.335, d2=0.567 g=1.312
# 2/2 [==============================] - 1s 380ms/step
# Epoch>1, Batch104/390, d1=0.324, d2=0.382 g=1.581
# 2/2 [==============================] - 1s 378ms/step
# Epoch>1, Batch105/390, d1=0.334, d2=0.298 g=1.741
# 2/2 [==============================] - 1s 710ms/step
# Epoch>1, Batch106/390, d1=0.442, d2=0.281 g=1.725
# 2/2 [==============================] - 1s 652ms/step
# Epoch>1, Batch107/390, d1=0.572, d2=0.338 g=1.541
# 2/2 [==============================] - 1s 668ms/step
# Epoch>1, Batch108/390, d1=0.489, d2=0.382 g=1.450
# 2/2 [==============================] - 1s 667ms/step
# Epoch>1, Batch109/390, d1=0.490, d2=0.380 g=1.347
# 2/2 [==============================] - 1s 393ms/step
# Epoch>1, Batch110/390, d1=0.549, d2=0.430 g=1.195
# 2/2 [==============================] - 1s 383ms/step
# Epoch>1, Batch111/390, d1=0.375, d2=0.450 g=1.142
# 2/2 [==============================] - 1s 631ms/step
# Epoch>1, Batch112/390, d1=0.385, d2=0.469 g=1.103
# 2/2 [==============================] - 1s 674ms/step
# Epoch>1, Batch113/390, d1=0.400, d2=0.487 g=1.037
# 2/2 [==============================] - 1s 383ms/step
# Epoch>1, Batch114/390, d1=0.441, d2=0.530 g=0.968
# 2/2 [==============================] - 1s 381ms/step
# Epoch>1, Batch115/390, d1=0.431, d2=0.558 g=0.916
# 2/2 [==============================] - 1s 387ms/step
# Epoch>1, Batch116/390, d1=0.322, d2=0.553 g=0.933
# 2/2 [==============================] - 1s 384ms/step
# Epoch>1, Batch117/390, d1=0.248, d2=0.524 g=0.989
# 2/2 [==============================] - 1s 484ms/step
# Epoch>1, Batch118/390, d1=0.217, d2=0.472 g=1.076
# 2/2 [==============================] - 1s 621ms/step
# Epoch>1, Batch119/390, d1=0.201, d2=0.417 g=1.195
# 2/2 [==============================] - 1s 376ms/step
# Epoch>1, Batch120/390, d1=0.195, d2=0.371 g=1.278
# 2/2 [==============================] - 1s 411ms/step
# Epoch>1, Batch121/390, d1=0.135, d2=0.336 g=1.380
# 2/2 [==============================] - 1s 391ms/step
# Epoch>1, Batch122/390, d1=0.118, d2=0.310 g=1.444
# 2/2 [==============================] - 1s 386ms/step
# Epoch>1, Batch123/390, d1=0.153, d2=0.300 g=1.450
# 2/2 [==============================] - 1s 394ms/step
# Epoch>1, Batch124/390, d1=0.117, d2=0.305 g=1.418
# 2/2 [==============================] - 1s 366ms/step
# Epoch>1, Batch125/390, d1=0.111, d2=0.314 g=1.380
# 2/2 [==============================] - 1s 394ms/step
# Epoch>1, Batch126/390, d1=0.095, d2=0.343 g=1.308
# 2/2 [==============================] - 1s 462ms/step
# Epoch>1, Batch127/390, d1=0.111, d2=0.369 g=1.245
# 2/2 [==============================] - 1s 615ms/step
# Epoch>1, Batch128/390, d1=0.123, d2=0.415 g=1.187
# 2/2 [==============================] - 1s 665ms/step
# Epoch>1, Batch129/390, d1=0.108, d2=0.440 g=1.174
# 2/2 [==============================] - 1s 381ms/step
# Epoch>1, Batch130/390, d1=0.140, d2=0.458 g=1.177
# 2/2 [==============================] - 1s 400ms/step
# Epoch>1, Batch131/390, d1=0.201, d2=0.472 g=1.201
# 2/2 [==============================] - 1s 381ms/step
# Epoch>1, Batch132/390, d1=0.203, d2=0.427 g=1.266
# 2/2 [==============================] - 1s 408ms/step
# Epoch>1, Batch133/390, d1=0.223, d2=0.407 g=1.362
# 2/2 [==============================] - 1s 386ms/step
# Epoch>1, Batch134/390, d1=0.209, d2=0.355 g=1.393
# 2/2 [==============================] - 1s 385ms/step
# Epoch>1, Batch135/390, d1=0.322, d2=0.371 g=1.298
# 2/2 [==============================] - 1s 377ms/step
# Epoch>1, Batch136/390, d1=0.312, d2=0.405 g=1.238
# 2/2 [==============================] - 1s 384ms/step
# Epoch>1, Batch137/390, d1=0.182, d2=0.406 g=1.279
# 2/2 [==============================] - 1s 386ms/step
# Epoch>1, Batch138/390, d1=0.333, d2=0.401 g=1.243
# 2/2 [==============================] - 1s 384ms/step
# Epoch>1, Batch139/390, d1=0.220, d2=0.453 g=1.221
# 2/2 [==============================] - 1s 378ms/step
# Epoch>1, Batch140/390, d1=0.269, d2=0.610 g=1.055
# 2/2 [==============================] - 1s 383ms/step
# Epoch>1, Batch141/390, d1=0.179, d2=1.827 g=0.561
# 2/2 [==============================] - 1s 376ms/step
# Epoch>1, Batch142/390, d1=0.211, d2=4.376 g=0.286
# 2/2 [==============================] - 1s 387ms/step
# Epoch>1, Batch143/390, d1=0.171, d2=2.870 g=1.299
# 2/2 [==============================] - 1s 372ms/step
# Epoch>1, Batch144/390, d1=0.267, d2=0.265 g=3.301
# 2/2 [==============================] - 1s 392ms/step
# Epoch>1, Batch145/390, d1=0.592, d2=0.058 g=3.619
# 2/2 [==============================] - 1s 386ms/step
# Epoch>1, Batch146/390, d1=0.515, d2=0.115 g=2.867
# 2/2 [==============================] - 1s 385ms/step
# Epoch>1, Batch147/390, d1=0.494, d2=0.341 g=1.971
# 2/2 [==============================] - 1s 446ms/step
# Epoch>1, Batch148/390, d1=0.608, d2=0.545 g=1.549
# 2/2 [==============================] - 1s 615ms/step
# Epoch>1, Batch149/390, d1=0.679, d2=0.645 g=1.434
# 2/2 [==============================] - 1s 681ms/step
# Epoch>1, Batch150/390, d1=0.621, d2=0.578 g=1.535
# 2/2 [==============================] - 1s 385ms/step
# Epoch>1, Batch151/390, d1=0.523, d2=0.503 g=1.938
# 2/2 [==============================] - 1s 384ms/step
# Epoch>1, Batch152/390, d1=0.445, d2=0.442 g=2.282
# 2/2 [==============================] - 1s 390ms/step
# Epoch>1, Batch153/390, d1=0.616, d2=0.850 g=2.235
# 2/2 [==============================] - 1s 383ms/step
# Epoch>1, Batch154/390, d1=0.455, d2=1.236 g=2.784
# 2/2 [==============================] - 1s 391ms/step
# Epoch>1, Batch155/390, d1=0.748, d2=0.421 g=3.686
# 2/2 [==============================] - 1s 407ms/step
# Epoch>1, Batch156/390, d1=1.056, d2=0.197 g=3.208
# 2/2 [==============================] - 1s 379ms/step
# Epoch>1, Batch157/390, d1=1.251, d2=0.509 g=3.127
# 2/2 [==============================] - 1s 627ms/step
# Epoch>1, Batch158/390, d1=1.581, d2=0.094 g=3.200
# 2/2 [==============================] - 1s 701ms/step
# Epoch>1, Batch159/390, d1=1.326, d2=0.122 g=2.741
# 2/2 [==============================] - 1s 695ms/step
# Epoch>1, Batch160/390, d1=0.865, d2=0.179 g=2.632
# 2/2 [==============================] - 1s 720ms/step
# Epoch>1, Batch161/390, d1=0.858, d2=0.216 g=2.582
# 2/2 [==============================] - 1s 440ms/step
# Epoch>1, Batch162/390, d1=0.824, d2=0.191 g=2.632
# 2/2 [==============================] - 1s 585ms/step
# Epoch>1, Batch163/390, d1=0.647, d2=0.135 g=2.629
# 2/2 [==============================] - 1s 391ms/step
# Epoch>1, Batch164/390, d1=0.489, d2=0.183 g=2.737
# 2/2 [==============================] - 1s 382ms/step
# Epoch>1, Batch165/390, d1=0.561, d2=0.281 g=2.726
# 2/2 [==============================] - 1s 382ms/step
# Epoch>1, Batch166/390, d1=0.600, d2=0.635 g=3.153
# 2/2 [==============================] - 1s 376ms/step
# Epoch>1, Batch167/390, d1=0.774, d2=0.141 g=3.242
# 2/2 [==============================] - 1s 379ms/step
# Epoch>1, Batch168/390, d1=0.836, d2=0.107 g=2.880
# 2/2 [==============================] - 1s 376ms/step
# Epoch>1, Batch169/390, d1=0.672, d2=0.114 g=2.695
# 2/2 [==============================] - 1s 366ms/step
# Epoch>1, Batch170/390, d1=0.799, d2=0.140 g=2.633
# 2/2 [==============================] - 1s 395ms/step
# Epoch>1, Batch171/390, d1=0.491, d2=0.111 g=2.904
# 2/2 [==============================] - 1s 401ms/step
# Epoch>1, Batch172/390, d1=0.586, d2=0.084 g=3.033
# 2/2 [==============================] - 1s 411ms/step
# Epoch>1, Batch173/390, d1=0.443, d2=0.081 g=2.951
# 2/2 [==============================] - 1s 409ms/step
# Epoch>1, Batch174/390, d1=0.380, d2=0.096 g=3.109
# 2/2 [==============================] - 1s 400ms/step
# Epoch>1, Batch175/390, d1=0.276, d2=0.066 g=3.156
# 2/2 [==============================] - 1s 401ms/step
# Epoch>1, Batch176/390, d1=0.239, d2=0.087 g=3.139
# 2/2 [==============================] - 1s 402ms/step
# Epoch>1, Batch177/390, d1=0.388, d2=0.129 g=2.782
# 2/2 [==============================] - 1s 390ms/step
# Epoch>1, Batch178/390, d1=0.366, d2=0.271 g=2.602
# 2/2 [==============================] - 1s 396ms/step
# Epoch>1, Batch179/390, d1=0.424, d2=0.647 g=2.629
# 2/2 [==============================] - 1s 394ms/step
# Epoch>1, Batch180/390, d1=0.504, d2=0.133 g=3.080
# 2/2 [==============================] - 1s 375ms/step
# Epoch>1, Batch181/390, d1=0.842, d2=0.101 g=2.750
# 2/2 [==============================] - 1s 394ms/step
# Epoch>1, Batch182/390, d1=0.742, d2=0.145 g=2.561
# 2/2 [==============================] - 1s 380ms/step
# Epoch>1, Batch183/390, d1=0.789, d2=0.163 g=2.332
# 2/2 [==============================] - 1s 707ms/step
# Epoch>1, Batch184/390, d1=0.502, d2=0.196 g=2.542
# 2/2 [==============================] - 1s 696ms/step
# Epoch>1, Batch185/390, d1=0.690, d2=0.192 g=2.455
# 2/2 [==============================] - 1s 693ms/step
# Epoch>1, Batch186/390, d1=0.680, d2=0.220 g=2.271
# 2/2 [==============================] - 1s 651ms/step
# Epoch>1, Batch187/390, d1=0.626, d2=0.368 g=2.011
# 2/2 [==============================] - 1s 374ms/step
# Epoch>1, Batch188/390, d1=0.549, d2=0.354 g=1.999
# 2/2 [==============================] - 1s 719ms/step
# Epoch>1, Batch189/390, d1=0.733, d2=0.214 g=2.347
# 2/2 [==============================] - 1s 376ms/step
# Epoch>1, Batch190/390, d1=0.546, d2=0.149 g=2.422
# 2/2 [==============================] - 1s 441ms/step
# Epoch>1, Batch191/390, d1=0.629, d2=0.131 g=2.439
# 2/2 [==============================] - 1s 721ms/step
# Epoch>1, Batch192/390, d1=0.707, d2=0.153 g=2.402
# 2/2 [==============================] - 1s 391ms/step
# Epoch>1, Batch193/390, d1=0.479, d2=0.135 g=2.306
# 2/2 [==============================] - 1s 703ms/step
# Epoch>1, Batch194/390, d1=0.387, d2=0.217 g=2.134
# 2/2 [==============================] - 1s 405ms/step
# Epoch>1, Batch195/390, d1=0.681, d2=0.240 g=1.913
# 2/2 [==============================] - 1s 366ms/step
# Epoch>1, Batch196/390, d1=0.422, d2=0.336 g=1.648
# 2/2 [==============================] - 1s 392ms/step
# Epoch>1, Batch197/390, d1=0.273, d2=0.468 g=1.636
# 2/2 [==============================] - 1s 406ms/step
# Epoch>1, Batch198/390, d1=0.293, d2=0.376 g=1.737
# 2/2 [==============================] - 1s 683ms/step
# Epoch>1, Batch199/390, d1=0.318, d2=0.469 g=1.691
# 2/2 [==============================] - 1s 708ms/step
# Epoch>1, Batch200/390, d1=0.345, d2=0.837 g=1.368
# 2/2 [==============================] - 1s 761ms/step
# Epoch>1, Batch201/390, d1=0.248, d2=1.735 g=1.104
# 2/2 [==============================] - 1s 564ms/step
# Epoch>1, Batch202/390, d1=0.314, d2=1.825 g=1.554
# 2/2 [==============================] - 1s 388ms/step
# Epoch>1, Batch203/390, d1=0.346, d2=0.528 g=2.663
# 2/2 [==============================] - 1s 688ms/step
# Epoch>1, Batch204/390, d1=0.620, d2=0.165 g=3.014
# 2/2 [==============================] - 1s 678ms/step
# Epoch>1, Batch205/390, d1=0.755, d2=0.227 g=2.198
# 2/2 [==============================] - 1s 696ms/step
# Epoch>1, Batch206/390, d1=0.834, d2=0.473 g=1.637
# 2/2 [==============================] - 1s 415ms/step
# Epoch>1, Batch207/390, d1=0.953, d2=0.607 g=1.471
# 2/2 [==============================] - 1s 381ms/step
# Epoch>1, Batch208/390, d1=0.959, d2=0.601 g=1.461
# 2/2 [==============================] - 1s 395ms/step
# Epoch>1, Batch209/390, d1=0.694, d2=0.362 g=1.643
# 2/2 [==============================] - 1s 404ms/step
# Epoch>1, Batch210/390, d1=0.839, d2=0.302 g=1.735
# 2/2 [==============================] - 1s 379ms/step
# Epoch>1, Batch211/390, d1=0.713, d2=0.312 g=1.665
# 2/2 [==============================] - 1s 399ms/step
# Epoch>1, Batch212/390, d1=0.596, d2=0.411 g=1.514
# 2/2 [==============================] - 1s 382ms/step
# Epoch>1, Batch213/390, d1=0.470, d2=0.334 g=1.634
# 2/2 [==============================] - 1s 378ms/step
# Epoch>1, Batch214/390, d1=0.567, d2=0.331 g=1.686
# 2/2 [==============================] - 1s 405ms/step
# Epoch>1, Batch215/390, d1=0.657, d2=0.314 g=1.834
# 2/2 [==============================] - 1s 390ms/step
# Epoch>1, Batch216/390, d1=0.341, d2=0.297 g=1.844
# 2/2 [==============================] - 1s 384ms/step
# Epoch>1, Batch217/390, d1=0.355, d2=0.266 g=2.029
# 2/2 [==============================] - 1s 387ms/step
# Epoch>1, Batch218/390, d1=0.388, d2=0.301 g=1.987
# 2/2 [==============================] - 1s 391ms/step
# Epoch>1, Batch219/390, d1=0.302, d2=0.282 g=1.932
# 2/2 [==============================] - 1s 372ms/step
# Epoch>1, Batch220/390, d1=0.376, d2=0.395 g=1.744
# 2/2 [==============================] - 1s 390ms/step
# Epoch>1, Batch221/390, d1=0.374, d2=0.371 g=1.562
# 2/2 [==============================] - 1s 408ms/step
# Epoch>1, Batch222/390, d1=0.271, d2=0.561 g=1.446
# 2/2 [==============================] - 1s 404ms/step
# Epoch>1, Batch223/390, d1=0.265, d2=0.572 g=1.191
# 2/2 [==============================] - 1s 394ms/step
# Epoch>1, Batch224/390, d1=0.271, d2=0.781 g=1.074
# 2/2 [==============================] - 1s 675ms/step
# Epoch>1, Batch225/390, d1=0.369, d2=0.723 g=0.860
# 2/2 [==============================] - 2s 748ms/step
# Epoch>1, Batch226/390, d1=0.292, d2=0.615 g=0.882
# 2/2 [==============================] - 1s 389ms/step
# Epoch>1, Batch227/390, d1=0.238, d2=0.703 g=0.919
# 2/2 [==============================] - 1s 393ms/step
# Epoch>1, Batch228/390, d1=0.321, d2=0.673 g=0.931
# 2/2 [==============================] - 1s 538ms/step
# Epoch>1, Batch229/390, d1=0.356, d2=0.611 g=0.909
# 2/2 [==============================] - 1s 717ms/step
# Epoch>1, Batch230/390, d1=0.391, d2=0.730 g=0.954
# 2/2 [==============================] - 1s 413ms/step
# Epoch>1, Batch231/390, d1=0.407, d2=0.782 g=0.835
# 2/2 [==============================] - 1s 453ms/step
# Epoch>1, Batch232/390, d1=0.394, d2=0.799 g=0.831
# 2/2 [==============================] - 1s 556ms/step
# Epoch>1, Batch233/390, d1=0.513, d2=0.817 g=0.811
# 2/2 [==============================] - 1s 731ms/step
# Epoch>1, Batch234/390, d1=0.484, d2=0.772 g=0.926
# 2/2 [==============================] - 1s 500ms/step
# Epoch>1, Batch235/390, d1=0.531, d2=0.658 g=0.886
# 2/2 [==============================] - 1s 394ms/step
# Epoch>1, Batch236/390, d1=0.491, d2=0.652 g=1.049
# 2/2 [==============================] - 1s 387ms/step
# Epoch>1, Batch237/390, d1=0.582, d2=0.559 g=1.104
# 2/2 [==============================] - 1s 379ms/step
# Epoch>1, Batch238/390, d1=0.629, d2=0.541 g=1.136
# 2/2 [==============================] - 1s 396ms/step
# Epoch>1, Batch239/390, d1=0.561, d2=0.463 g=1.216
# 2/2 [==============================] - 1s 396ms/step
# Epoch>1, Batch240/390, d1=0.611, d2=0.504 g=1.228
# 2/2 [==============================] - 1s 391ms/step
# Epoch>1, Batch241/390, d1=0.662, d2=0.485 g=1.318
# 2/2 [==============================] - 1s 376ms/step
# Epoch>1, Batch242/390, d1=0.719, d2=0.413 g=1.315
# 2/2 [==============================] - 1s 380ms/step
# Epoch>1, Batch243/390, d1=0.578, d2=0.446 g=1.327
# 2/2 [==============================] - 1s 414ms/step
# Epoch>1, Batch244/390, d1=0.609, d2=0.398 g=1.332
# 2/2 [==============================] - 1s 390ms/step
# Epoch>1, Batch245/390, d1=0.616, d2=0.468 g=1.375
# 2/2 [==============================] - 1s 388ms/step
# Epoch>1, Batch246/390, d1=0.670, d2=0.380 g=1.370
# 2/2 [==============================] - 1s 398ms/step
# Epoch>1, Batch247/390, d1=0.622, d2=0.406 g=1.358
# 2/2 [==============================] - 1s 398ms/step
# Epoch>1, Batch248/390, d1=0.601, d2=0.418 g=1.309
# 2/2 [==============================] - 1s 385ms/step
# Epoch>1, Batch249/390, d1=0.743, d2=0.458 g=1.296
# 2/2 [==============================] - 1s 399ms/step
# Epoch>1, Batch250/390, d1=0.621, d2=0.456 g=1.309
# 2/2 [==============================] - 1s 409ms/step
# Epoch>1, Batch251/390, d1=0.626, d2=0.381 g=1.299
# 2/2 [==============================] - 1s 402ms/step
# Epoch>1, Batch252/390, d1=0.648, d2=0.419 g=1.250
# 2/2 [==============================] - 1s 376ms/step
# Epoch>1, Batch253/390, d1=0.552, d2=0.467 g=1.266
# 2/2 [==============================] - 1s 399ms/step
# Epoch>1, Batch254/390, d1=0.567, d2=0.452 g=1.142
# 2/2 [==============================] - 1s 368ms/step
# Epoch>1, Batch255/390, d1=0.673, d2=0.464 g=1.212
# 2/2 [==============================] - 1s 387ms/step
# Epoch>1, Batch256/390, d1=0.479, d2=0.479 g=1.175
# 2/2 [==============================] - 1s 505ms/step
# Epoch>1, Batch257/390, d1=0.642, d2=0.485 g=1.113
# 2/2 [==============================] - 1s 506ms/step
# Epoch>1, Batch258/390, d1=0.602, d2=0.493 g=1.096
# 2/2 [==============================] - 1s 739ms/step
# Epoch>1, Batch259/390, d1=0.625, d2=0.531 g=1.028
# 2/2 [==============================] - 1s 415ms/step
# Epoch>1, Batch260/390, d1=0.448, d2=0.528 g=1.077
# 2/2 [==============================] - 1s 721ms/step
# Epoch>1, Batch261/390, d1=0.540, d2=0.490 g=1.139
# 2/2 [==============================] - 1s 706ms/step
# Epoch>1, Batch262/390, d1=0.510, d2=0.577 g=1.041
# 2/2 [==============================] - 1s 394ms/step
# Epoch>1, Batch263/390, d1=0.566, d2=0.557 g=1.078
# 2/2 [==============================] - 1s 398ms/step
# Epoch>1, Batch264/390, d1=0.467, d2=0.524 g=1.078
# 2/2 [==============================] - 1s 394ms/step
# Epoch>1, Batch265/390, d1=0.507, d2=0.557 g=1.018
# 2/2 [==============================] - 1s 394ms/step
# Epoch>1, Batch266/390, d1=0.558, d2=0.573 g=1.049
# 2/2 [==============================] - 1s 388ms/step
# Epoch>1, Batch267/390, d1=0.485, d2=0.545 g=1.009
# 2/2 [==============================] - 1s 395ms/step
# Epoch>1, Batch268/390, d1=0.464, d2=0.667 g=0.992
# 2/2 [==============================] - 1s 398ms/step
# Epoch>1, Batch269/390, d1=0.633, d2=0.595 g=0.966
# 2/2 [==============================] - 1s 390ms/step
# Epoch>1, Batch270/390, d1=0.479, d2=0.576 g=0.982
# 2/2 [==============================] - 1s 383ms/step
# Epoch>1, Batch271/390, d1=0.556, d2=0.586 g=0.974
# 2/2 [==============================] - 1s 393ms/step
# Epoch>1, Batch272/390, d1=0.465, d2=0.632 g=0.982
# 2/2 [==============================] - 1s 388ms/step
# Epoch>1, Batch273/390, d1=0.499, d2=0.541 g=1.016
# 2/2 [==============================] - 1s 383ms/step
# Epoch>1, Batch274/390, d1=0.447, d2=0.500 g=1.025
# 2/2 [==============================] - 1s 388ms/step
# Epoch>1, Batch275/390, d1=0.611, d2=0.595 g=0.976
# 2/2 [==============================] - 1s 376ms/step
# Epoch>1, Batch276/390, d1=0.473, d2=0.600 g=0.950
# 2/2 [==============================] - 1s 390ms/step
# Epoch>1, Batch277/390, d1=0.623, d2=0.629 g=0.904
# 2/2 [==============================] - 1s 418ms/step
# Epoch>1, Batch278/390, d1=0.555, d2=0.656 g=0.957
# 2/2 [==============================] - 1s 382ms/step
# Epoch>1, Batch279/390, d1=0.465, d2=0.644 g=0.894
# 2/2 [==============================] - 1s 402ms/step
# Epoch>1, Batch280/390, d1=0.479, d2=0.682 g=0.903
# 2/2 [==============================] - 1s 403ms/step
# Epoch>1, Batch281/390, d1=0.555, d2=0.682 g=0.893
# 2/2 [==============================] - 1s 398ms/step
# Epoch>1, Batch282/390, d1=0.516, d2=0.616 g=0.814
# 2/2 [==============================] - 1s 390ms/step
# Epoch>1, Batch283/390, d1=0.554, d2=0.712 g=0.849
# 2/2 [==============================] - 1s 377ms/step
# Epoch>1, Batch284/390, d1=0.462, d2=0.730 g=0.851
# 2/2 [==============================] - 1s 397ms/step
# Epoch>1, Batch285/390, d1=0.498, d2=0.773 g=0.810
# 2/2 [==============================] - 1s 369ms/step
# Epoch>1, Batch286/390, d1=0.527, d2=0.797 g=0.835
# 2/2 [==============================] - 1s 365ms/step
# Epoch>1, Batch287/390, d1=0.473, d2=0.752 g=0.777
# 2/2 [==============================] - 1s 650ms/step
# Epoch>1, Batch288/390, d1=0.574, d2=0.806 g=0.727
# 2/2 [==============================] - 1s 672ms/step
# Epoch>1, Batch289/390, d1=0.512, d2=0.870 g=0.722
# 2/2 [==============================] - 1s 379ms/step
# Epoch>1, Batch290/390, d1=0.559, d2=0.908 g=0.688
# 2/2 [==============================] - 1s 680ms/step
# Epoch>1, Batch291/390, d1=0.529, d2=0.986 g=0.641
# 2/2 [==============================] - 1s 720ms/step
# Epoch>1, Batch292/390, d1=0.569, d2=0.938 g=0.637
# 2/2 [==============================] - 1s 479ms/step
# Epoch>1, Batch293/390, d1=0.563, d2=0.995 g=0.645
# 2/2 [==============================] - 1s 375ms/step
# Epoch>1, Batch294/390, d1=0.603, d2=0.908 g=0.718
# 2/2 [==============================] - 1s 377ms/step
# Epoch>1, Batch295/390, d1=0.725, d2=1.040 g=0.727
# 2/2 [==============================] - 1s 404ms/step
# Epoch>1, Batch296/390, d1=0.609, d2=0.876 g=0.634
# 2/2 [==============================] - 1s 383ms/step
# Epoch>1, Batch297/390, d1=0.703, d2=0.905 g=0.673
# 2/2 [==============================] - 1s 402ms/step
# Epoch>1, Batch298/390, d1=0.604, d2=0.866 g=0.682
# 2/2 [==============================] - 1s 376ms/step
# Epoch>1, Batch299/390, d1=0.671, d2=0.899 g=0.774
# 2/2 [==============================] - 1s 409ms/step
# Epoch>1, Batch300/390, d1=0.625, d2=0.830 g=0.833
# 2/2 [==============================] - 1s 408ms/step
# Epoch>1, Batch301/390, d1=0.678, d2=0.719 g=0.867
# 2/2 [==============================] - 1s 398ms/step
# Epoch>1, Batch302/390, d1=0.594, d2=0.599 g=0.969
# 2/2 [==============================] - 1s 385ms/step
# Epoch>1, Batch303/390, d1=0.551, d2=0.626 g=1.001
# 2/2 [==============================] - 1s 373ms/step
# Epoch>1, Batch304/390, d1=0.650, d2=0.609 g=1.055
# 2/2 [==============================] - 1s 394ms/step
# Epoch>1, Batch305/390, d1=0.557, d2=0.531 g=1.065
# 2/2 [==============================] - 1s 386ms/step
# Epoch>1, Batch306/390, d1=0.618, d2=0.516 g=1.109
# 2/2 [==============================] - 1s 386ms/step
# Epoch>1, Batch307/390, d1=0.573, d2=0.495 g=1.180
# 2/2 [==============================] - 1s 393ms/step
# Epoch>1, Batch308/390, d1=0.517, d2=0.411 g=1.262
# 2/2 [==============================] - 1s 383ms/step
# Epoch>1, Batch309/390, d1=0.600, d2=0.373 g=1.351
# 2/2 [==============================] - 1s 375ms/step
# Epoch>1, Batch310/390, d1=0.492, d2=0.373 g=1.320
# 2/2 [==============================] - 1s 372ms/step
# Epoch>1, Batch311/390, d1=0.601, d2=0.405 g=1.291
# 2/2 [==============================] - 1s 376ms/step
# Epoch>1, Batch312/390, d1=0.515, d2=0.435 g=1.223
# 2/2 [==============================] - 1s 702ms/step
# Epoch>1, Batch313/390, d1=0.459, d2=0.435 g=1.224
# 2/2 [==============================] - 1s 387ms/step
# Epoch>1, Batch314/390, d1=0.505, d2=0.421 g=1.152
# 2/2 [==============================] - 1s 396ms/step
# Epoch>1, Batch315/390, d1=0.424, d2=0.521 g=1.101
# 2/2 [==============================] - 1s 486ms/step
# Epoch>1, Batch316/390, d1=0.522, d2=0.600 g=1.038
# 2/2 [==============================] - 1s 727ms/step
# Epoch>1, Batch317/390, d1=0.532, d2=0.692 g=1.141
# 2/2 [==============================] - 1s 667ms/step
# Epoch>1, Batch318/390, d1=0.588, d2=0.571 g=1.319
# 2/2 [==============================] - 1s 381ms/step
# Epoch>1, Batch319/390, d1=0.638, d2=0.549 g=1.405
# 2/2 [==============================] - 1s 402ms/step
# Epoch>1, Batch320/390, d1=0.665, d2=0.514 g=1.478
# 2/2 [==============================] - 1s 704ms/step
# Epoch>1, Batch321/390, d1=0.588, d2=0.482 g=1.579
# 2/2 [==============================] - 1s 723ms/step
# Epoch>1, Batch322/390, d1=0.626, d2=0.487 g=1.643
# 2/2 [==============================] - 1s 717ms/step
# Epoch>1, Batch323/390, d1=0.879, d2=0.555 g=1.402
# 2/2 [==============================] - 1s 582ms/step
# Epoch>1, Batch324/390, d1=0.753, d2=0.834 g=1.271
# 2/2 [==============================] - 1s 662ms/step
# Epoch>1, Batch325/390, d1=0.922, d2=0.799 g=1.314
# 2/2 [==============================] - 1s 674ms/step
# Epoch>1, Batch326/390, d1=1.017, d2=0.859 g=1.099
# 2/2 [==============================] - 1s 507ms/step
# Epoch>1, Batch327/390, d1=1.089, d2=0.680 g=0.982
# 2/2 [==============================] - 1s 429ms/step
# Epoch>1, Batch328/390, d1=0.985, d2=0.711 g=1.013
# 2/2 [==============================] - 1s 626ms/step
# Epoch>1, Batch329/390, d1=1.031, d2=0.703 g=1.128
# 2/2 [==============================] - 1s 455ms/step
# Epoch>1, Batch330/390, d1=1.086, d2=0.568 g=1.212
# 2/2 [==============================] - 1s 403ms/step
# Epoch>1, Batch331/390, d1=1.081, d2=0.501 g=1.263
# 2/2 [==============================] - 1s 400ms/step
# Epoch>1, Batch332/390, d1=0.951, d2=0.546 g=1.173
# 2/2 [==============================] - 1s 395ms/step
# Epoch>1, Batch333/390, d1=0.970, d2=0.614 g=1.274
# 2/2 [==============================] - 1s 388ms/step
# Epoch>1, Batch334/390, d1=0.994, d2=0.582 g=1.277
# 2/2 [==============================] - 1s 402ms/step
# Epoch>1, Batch335/390, d1=0.962, d2=0.526 g=1.262
# 2/2 [==============================] - 1s 389ms/step
# Epoch>1, Batch336/390, d1=1.005, d2=0.596 g=1.262
# 2/2 [==============================] - 1s 387ms/step
# Epoch>1, Batch337/390, d1=0.923, d2=0.490 g=1.242
# 2/2 [==============================] - 1s 394ms/step
# Epoch>1, Batch338/390, d1=1.000, d2=0.542 g=1.225
# 2/2 [==============================] - 1s 386ms/step
# Epoch>1, Batch339/390, d1=0.915, d2=0.451 g=1.274
# 2/2 [==============================] - 1s 365ms/step
# Epoch>1, Batch340/390, d1=0.850, d2=0.427 g=1.237
# 2/2 [==============================] - 1s 391ms/step
# Epoch>1, Batch341/390, d1=0.912, d2=0.505 g=1.226
# 2/2 [==============================] - 1s 402ms/step
# Epoch>1, Batch342/390, d1=0.854, d2=0.447 g=1.233
# 2/2 [==============================] - 1s 388ms/step
# Epoch>1, Batch343/390, d1=0.882, d2=0.446 g=1.131
# 2/2 [==============================] - 1s 384ms/step
# Epoch>1, Batch344/390, d1=0.847, d2=0.527 g=1.219
# 2/2 [==============================] - 1s 392ms/step
# Epoch>1, Batch345/390, d1=0.852, d2=0.542 g=1.161
# 2/2 [==============================] - 1s 383ms/step
# Epoch>1, Batch346/390, d1=0.888, d2=0.485 g=1.074
# 2/2 [==============================] - 1s 377ms/step
# Epoch>1, Batch347/390, d1=0.763, d2=0.513 g=1.096
# 2/2 [==============================] - 1s 407ms/step
# Epoch>1, Batch348/390, d1=0.793, d2=0.496 g=1.129
# 2/2 [==============================] - 1s 403ms/step
# Epoch>1, Batch349/390, d1=0.798, d2=0.498 g=1.170
# 2/2 [==============================] - 1s 385ms/step
# Epoch>1, Batch350/390, d1=0.723, d2=0.499 g=1.218
# 2/2 [==============================] - 1s 375ms/step
# Epoch>1, Batch351/390, d1=0.794, d2=0.551 g=1.097
# 2/2 [==============================] - 1s 367ms/step
# Epoch>1, Batch352/390, d1=0.815, d2=0.474 g=1.174
# 2/2 [==============================] - 1s 387ms/step
# Epoch>1, Batch353/390, d1=0.860, d2=0.495 g=1.148
# 2/2 [==============================] - 1s 404ms/step
# Epoch>1, Batch354/390, d1=0.780, d2=0.489 g=1.173
# 2/2 [==============================] - 1s 390ms/step
# Epoch>1, Batch355/390, d1=0.786, d2=0.491 g=1.174
# 2/2 [==============================] - 1s 379ms/step
# Epoch>1, Batch356/390, d1=0.793, d2=0.536 g=1.117
# 2/2 [==============================] - 1s 383ms/step
# Epoch>1, Batch357/390, d1=0.865, d2=0.520 g=1.213
# 2/2 [==============================] - 1s 391ms/step
# Epoch>1, Batch358/390, d1=0.821, d2=0.542 g=1.111
# 2/2 [==============================] - 1s 386ms/step
# Epoch>1, Batch359/390, d1=0.837, d2=0.522 g=1.170
# 2/2 [==============================] - 1s 395ms/step
# Epoch>1, Batch360/390, d1=0.799, d2=0.524 g=1.120
# 2/2 [==============================] - 1s 386ms/step
# Epoch>1, Batch361/390, d1=0.772, d2=0.551 g=1.161
# 2/2 [==============================] - 1s 587ms/step
# Epoch>1, Batch362/390, d1=0.833, d2=0.576 g=1.237
# 2/2 [==============================] - 1s 377ms/step
# Epoch>1, Batch363/390, d1=0.796, d2=0.454 g=1.216
# 2/2 [==============================] - 1s 470ms/step
# Epoch>1, Batch364/390, d1=0.808, d2=0.526 g=1.115
# 2/2 [==============================] - 1s 391ms/step
# Epoch>1, Batch365/390, d1=0.761, d2=0.477 g=1.205
# 2/2 [==============================] - 1s 382ms/step
# Epoch>1, Batch366/390, d1=0.782, d2=0.459 g=1.210
# 2/2 [==============================] - 1s 476ms/step
# Epoch>1, Batch367/390, d1=0.785, d2=0.470 g=1.180
# 2/2 [==============================] - 1s 544ms/step
# Epoch>1, Batch368/390, d1=0.698, d2=0.485 g=1.214
# 2/2 [==============================] - 1s 389ms/step
# Epoch>1, Batch369/390, d1=0.699, d2=0.486 g=1.106
# 2/2 [==============================] - 1s 377ms/step
# Epoch>1, Batch370/390, d1=0.707, d2=0.540 g=1.168
# 2/2 [==============================] - 1s 401ms/step
# Epoch>1, Batch371/390, d1=0.736, d2=0.486 g=1.079
# 2/2 [==============================] - 1s 394ms/step
# Epoch>1, Batch372/390, d1=0.719, d2=0.498 g=1.124
# 2/2 [==============================] - 1s 491ms/step
# Epoch>1, Batch373/390, d1=0.742, d2=0.567 g=1.002
# 2/2 [==============================] - 1s 439ms/step
# Epoch>1, Batch374/390, d1=0.728, d2=0.609 g=0.961
# 2/2 [==============================] - 1s 565ms/step
# Epoch>1, Batch375/390, d1=0.610, d2=0.611 g=0.962
# 2/2 [==============================] - 1s 390ms/step
# Epoch>1, Batch376/390, d1=0.683, d2=0.655 g=0.919
# 2/2 [==============================] - 1s 373ms/step
# Epoch>1, Batch377/390, d1=0.688, d2=0.686 g=0.863
# 2/2 [==============================] - 1s 387ms/step
# Epoch>1, Batch378/390, d1=0.721, d2=0.672 g=0.798
# 2/2 [==============================] - 1s 389ms/step
# Epoch>1, Batch379/390, d1=0.721, d2=0.755 g=0.750
# 2/2 [==============================] - 1s 526ms/step
# Epoch>1, Batch380/390, d1=0.690, d2=0.780 g=0.721
# 2/2 [==============================] - 1s 695ms/step
# Epoch>1, Batch381/390, d1=0.731, d2=0.760 g=0.738
# 2/2 [==============================] - 1s 386ms/step
# Epoch>1, Batch382/390, d1=0.638, d2=0.782 g=0.718
# 2/2 [==============================] - 1s 381ms/step
# Epoch>1, Batch383/390, d1=0.734, d2=0.766 g=0.816
# 2/2 [==============================] - 1s 679ms/step
# Epoch>1, Batch384/390, d1=0.627, d2=0.685 g=0.839
# 2/2 [==============================] - 1s 408ms/step
# Epoch>1, Batch385/390, d1=0.669, d2=0.677 g=0.868
# 2/2 [==============================] - 1s 396ms/step
# Epoch>1, Batch386/390, d1=0.716, d2=0.577 g=0.963
# 2/2 [==============================] - 1s 391ms/step
# Epoch>1, Batch387/390, d1=0.614, d2=0.524 g=1.001
# 2/2 [==============================] - 1s 396ms/step
# Epoch>1, Batch388/390, d1=0.616, d2=0.537 g=1.075
# 2/2 [==============================] - 1s 388ms/step
# Epoch>1, Batch389/390, d1=0.635, d2=0.520 g=1.167
# 2/2 [==============================] - 1s 392ms/step
# Epoch>1, Batch390/390, d1=0.571, d2=0.478 g=1.106
# 2/2 [==============================] - 1s 370ms/step
# Epoch>2, Batch1/390, d1=0.595, d2=0.434 g=1.183
# 2/2 [==============================] - 1s 383ms/step
# Epoch>2, Batch2/390, d1=0.553, d2=0.462 g=1.187
# 2/2 [==============================] - 1s 368ms/step
# Epoch>2, Batch3/390, d1=0.579, d2=0.449 g=1.198
# 2/2 [==============================] - 1s 402ms/step
# Epoch>2, Batch4/390, d1=0.603, d2=0.463 g=1.153
# 2/2 [==============================] - 1s 392ms/step
# Epoch>2, Batch5/390, d1=0.524, d2=0.530 g=1.096
# 2/2 [==============================] - 1s 377ms/step
# Epoch>2, Batch6/390, d1=0.642, d2=0.552 g=1.015
# 2/2 [==============================] - 1s 389ms/step
# Epoch>2, Batch7/390, d1=0.523, d2=0.632 g=0.926
# 2/2 [==============================] - 1s 385ms/step
# Epoch>2, Batch8/390, d1=0.614, d2=0.692 g=0.883
# 2/2 [==============================] - 1s 380ms/step
# Epoch>2, Batch9/390, d1=0.667, d2=0.757 g=0.777
# 2/2 [==============================] - 1s 395ms/step
# Epoch>2, Batch10/390, d1=0.616, d2=0.798 g=0.786
# 2/2 [==============================] - 1s 388ms/step
# Epoch>2, Batch11/390, d1=0.700, d2=0.776 g=0.751
# 2/2 [==============================] - 1s 391ms/step
# Epoch>2, Batch12/390, d1=0.656, d2=0.761 g=0.801
# 2/2 [==============================] - 1s 376ms/step
# Epoch>2, Batch13/390, d1=0.764, d2=0.776 g=0.860
# 2/2 [==============================] - 1s 374ms/step
# Epoch>2, Batch14/390, d1=0.670, d2=0.651 g=0.892
# 2/2 [==============================] - 1s 378ms/step
# Epoch>2, Batch15/390, d1=0.618, d2=0.642 g=0.991
# 2/2 [==============================] - 1s 383ms/step
# Epoch>2, Batch16/390, d1=0.740, d2=0.615 g=1.001
# 2/2 [==============================] - 1s 385ms/step
# Epoch>2, Batch17/390, d1=0.725, d2=0.576 g=1.054
# 2/2 [==============================] - 1s 411ms/step
# Epoch>2, Batch18/390, d1=0.766, d2=0.542 g=1.068
# 2/2 [==============================] - 1s 381ms/step
# Epoch>2, Batch19/390, d1=0.765, d2=0.535 g=1.041
# 2/2 [==============================] - 1s 387ms/step
# Epoch>2, Batch20/390, d1=0.758, d2=0.569 g=1.037
# 2/2 [==============================] - 1s 384ms/step
# Epoch>2, Batch21/390, d1=0.743, d2=0.573 g=0.998
# 2/2 [==============================] - 1s 401ms/step
# Epoch>2, Batch22/390, d1=0.720, d2=0.582 g=0.960
# 2/2 [==============================] - 1s 397ms/step
# Epoch>2, Batch23/390, d1=0.842, d2=0.647 g=0.944
# 2/2 [==============================] - 1s 394ms/step
# Epoch>2, Batch24/390, d1=0.682, d2=0.640 g=0.921
# 2/2 [==============================] - 1s 405ms/step
# Epoch>2, Batch25/390, d1=0.751, d2=0.688 g=0.849
# 2/2 [==============================] - 1s 395ms/step
# Epoch>2, Batch26/390, d1=0.663, d2=0.695 g=0.848
# 2/2 [==============================] - 1s 383ms/step
# Epoch>2, Batch27/390, d1=0.684, d2=0.641 g=0.891
# 2/2 [==============================] - 1s 372ms/step
# Epoch>2, Batch28/390, d1=0.673, d2=0.649 g=0.963
# 2/2 [==============================] - 1s 380ms/step
# Epoch>2, Batch29/390, d1=0.799, d2=0.537 g=0.986
# 2/2 [==============================] - 1s 394ms/step
# Epoch>2, Batch30/390, d1=0.692, d2=0.536 g=1.096
# 2/2 [==============================] - 1s 406ms/step
# Epoch>2, Batch31/390, d1=0.781, d2=0.503 g=1.104
# 2/2 [==============================] - 1s 376ms/step
# Epoch>2, Batch32/390, d1=0.717, d2=0.507 g=1.082
# 2/2 [==============================] - 1s 395ms/step
# Epoch>2, Batch33/390, d1=0.720, d2=0.502 g=1.099
# 2/2 [==============================] - 1s 389ms/step
# Epoch>2, Batch34/390, d1=0.606, d2=0.496 g=1.087
# 2/2 [==============================] - 1s 381ms/step
# Epoch>2, Batch35/390, d1=0.594, d2=0.485 g=1.106
# 2/2 [==============================] - 1s 406ms/step
# Epoch>2, Batch36/390, d1=0.589, d2=0.514 g=1.023
# 2/2 [==============================] - 1s 379ms/step
# Epoch>2, Batch37/390, d1=0.587, d2=0.536 g=0.957
# 2/2 [==============================] - 1s 405ms/step
# Epoch>2, Batch38/390, d1=0.611, d2=0.619 g=0.894
# 2/2 [==============================] - 1s 388ms/step
# Epoch>2, Batch39/390, d1=0.620, d2=0.669 g=0.783
# 2/2 [==============================] - 1s 383ms/step
# Epoch>2, Batch40/390, d1=0.547, d2=0.795 g=0.719
# 2/2 [==============================] - 1s 372ms/step
# Epoch>2, Batch41/390, d1=0.639, d2=0.780 g=0.754
# 2/2 [==============================] - 1s 394ms/step
# Epoch>2, Batch42/390, d1=0.597, d2=0.858 g=0.692
# 2/2 [==============================] - 1s 399ms/step
# Epoch>2, Batch43/390, d1=0.601, d2=0.764 g=0.739
# 2/2 [==============================] - 1s 384ms/step
# Epoch>2, Batch44/390, d1=0.544, d2=0.753 g=0.786
# 2/2 [==============================] - 1s 391ms/step
# Epoch>2, Batch45/390, d1=0.588, d2=0.641 g=0.849
# 2/2 [==============================] - 1s 396ms/step
# Epoch>2, Batch46/390, d1=0.598, d2=0.660 g=0.930
# 2/2 [==============================] - 1s 393ms/step
# Epoch>2, Batch47/390, d1=0.618, d2=0.595 g=0.932
# 2/2 [==============================] - 1s 381ms/step
# Epoch>2, Batch48/390, d1=0.654, d2=0.579 g=0.978
# 2/2 [==============================] - 1s 396ms/step
# Epoch>2, Batch49/390, d1=0.652, d2=0.658 g=1.008
# 2/2 [==============================] - 1s 391ms/step
# Epoch>2, Batch50/390, d1=0.577, d2=0.533 g=0.985
# 2/2 [==============================] - 1s 383ms/step
# Epoch>2, Batch51/390, d1=0.610, d2=0.574 g=0.982
# 2/2 [==============================] - 1s 383ms/step
# Epoch>2, Batch52/390, d1=0.620, d2=0.635 g=0.900
# 2/2 [==============================] - 1s 391ms/step
# Epoch>2, Batch53/390, d1=0.767, d2=0.653 g=0.812
# 2/2 [==============================] - 1s 387ms/step
# Epoch>2, Batch54/390, d1=0.632, d2=0.723 g=0.810
# 2/2 [==============================] - 1s 380ms/step
# Epoch>2, Batch55/390, d1=0.646, d2=0.746 g=0.874
# 2/2 [==============================] - 1s 409ms/step
# Epoch>2, Batch56/390, d1=0.673, d2=0.606 g=0.906
# 2/2 [==============================] - 1s 395ms/step
# Epoch>2, Batch57/390, d1=0.653, d2=0.561 g=0.946
# 2/2 [==============================] - 1s 380ms/step
# Epoch>2, Batch58/390, d1=0.694, d2=0.536 g=0.983
# 2/2 [==============================] - 1s 380ms/step
# Epoch>2, Batch59/390, d1=0.652, d2=0.560 g=1.032
# 2/2 [==============================] - 1s 402ms/step
# Epoch>2, Batch60/390, d1=0.638, d2=0.539 g=1.034
# 2/2 [==============================] - 1s 389ms/step
# Epoch>2, Batch61/390, d1=0.715, d2=0.576 g=0.983
# 2/2 [==============================] - 1s 372ms/step
# Epoch>2, Batch62/390, d1=0.693, d2=0.582 g=0.912
# 2/2 [==============================] - 1s 384ms/step
# Epoch>2, Batch63/390, d1=0.734, d2=0.659 g=0.917
# 2/2 [==============================] - 1s 394ms/step
# Epoch>2, Batch64/390, d1=0.740, d2=0.681 g=0.863
# 2/2 [==============================] - 1s 399ms/step
# Epoch>2, Batch65/390, d1=0.764, d2=0.648 g=0.901
# 2/2 [==============================] - 1s 393ms/step
# Epoch>2, Batch66/390, d1=0.758, d2=0.596 g=0.913
# 2/2 [==============================] - 1s 390ms/step
# Epoch>2, Batch67/390, d1=0.685, d2=0.586 g=0.917
# 2/2 [==============================] - 1s 398ms/step
# Epoch>2, Batch68/390, d1=0.701, d2=0.524 g=0.972
# 2/2 [==============================] - 1s 381ms/step
# Epoch>2, Batch69/390, d1=0.722, d2=0.564 g=1.038
# 2/2 [==============================] - 1s 404ms/step
# Epoch>2, Batch70/390, d1=0.741, d2=0.537 g=1.005
# 2/2 [==============================] - 1s 374ms/step
# Epoch>2, Batch71/390, d1=0.701, d2=0.524 g=0.952
# 2/2 [==============================] - 1s 391ms/step
# Epoch>2, Batch72/390, d1=0.716, d2=0.608 g=0.924
# 2/2 [==============================] - 1s 418ms/step
# Epoch>2, Batch73/390, d1=0.750, d2=0.612 g=0.921
# 2/2 [==============================] - 1s 393ms/step
# Epoch>2, Batch74/390, d1=0.723, d2=0.609 g=0.895
# 2/2 [==============================] - 1s 417ms/step
# Epoch>2, Batch75/390, d1=0.723, d2=0.604 g=0.859
# 2/2 [==============================] - 1s 389ms/step
# Epoch>2, Batch76/390, d1=0.679, d2=0.640 g=0.839
# 2/2 [==============================] - 1s 388ms/step
# Epoch>2, Batch77/390, d1=0.660, d2=0.611 g=0.843
# 2/2 [==============================] - 1s 381ms/step
# ...
# Epoch>2, Batch237/390, d1=0.792, d2=0.731 g=0.871
# 2/2 [==============================] - 1s 386ms/step
# Epoch>2, Batch238/390, d1=0.776, d2=0.635 g=0.907
# 2/2 [==============================] - 1s 392ms/step
# Epoch>2, Batch239/390, d1=0.800, d2=0.602 g=0.951
# 2/2 [==============================] - 1s 409ms/step
# Epoch>2, Batch240/390, d1=0.747, d2=0.556 g=1.042
# 2/2 [==============================] - 1s 385ms/step
# Epoch>2, Batch241/390, d1=0.740, d2=0.583 g=0.973
# 2/2 [==============================] - 1s 395ms/step
# Epoch>2, Batch242/390, d1=0.771, d2=0.591 g=0.932
# 2/2 [==============================] - 1s 410ms/step
# Epoch>2, Batch243/390, d1=0.654, d2=0.554 g=0.994
# 2/2 [==============================] - 1s 387ms/step
# Epoch>2, Batch244/390, d1=0.688, d2=0.596 g=0.965
# 2/2 [==============================] - 1s 384ms/step
# Epoch>2, Batch245/390, d1=0.726, d2=0.635 g=0.970
# 2/2 [==============================] - 1s 391ms/step
# Epoch>2, Batch246/390, d1=0.697, d2=0.596 g=0.986
# 2/2 [==============================] - 1s 391ms/step
# Epoch>2, Batch247/390, d1=0.646, d2=0.606 g=0.980
# 2/2 [==============================] - 1s 377ms/step
# Epoch>2, Batch248/390, d1=0.658, d2=0.592 g=0.924
# 2/2 [==============================] - 1s 399ms/step
# Epoch>2, Batch249/390, d1=0.712, d2=0.615 g=0.958
# 2/2 [==============================] - 1s 395ms/step
# Epoch>2, Batch250/390, d1=0.674, d2=0.603 g=0.906
# 2/2 [==============================] - 1s 376ms/step
# Epoch>2, Batch251/390, d1=0.676, d2=0.686 g=0.901
# 2/2 [==============================] - 1s 377ms/step
# Epoch>2, Batch252/390, d1=0.618, d2=0.645 g=0.894
# 2/2 [==============================] - 1s 380ms/step
# Epoch>2, Batch253/390, d1=0.585, d2=0.645 g=0.937
# 2/2 [==============================] - 1s 375ms/step
# Epoch>2, Batch254/390, d1=0.573, d2=0.624 g=0.932
# 2/2 [==============================] - 1s 408ms/step
# Epoch>2, Batch255/390, d1=0.641, d2=0.652 g=0.917
# 2/2 [==============================] - 1s 391ms/step
# Epoch>2, Batch256/390, d1=0.612, d2=0.614 g=0.907
# 2/2 [==============================] - 1s 382ms/step
# Epoch>2, Batch257/390, d1=0.595, d2=0.637 g=0.895
# 2/2 [==============================] - 1s 375ms/step
# Epoch>2, Batch258/390, d1=0.576, d2=0.639 g=0.844
# 2/2 [==============================] - 1s 408ms/step
# Epoch>2, Batch259/390, d1=0.571, d2=0.650 g=0.839
# 2/2 [==============================] - 1s 405ms/step
# Epoch>2, Batch260/390, d1=0.607, d2=0.729 g=0.766
# 2/2 [==============================] - 1s 398ms/step
# Epoch>2, Batch261/390, d1=0.595, d2=0.737 g=0.781
# 2/2 [==============================] - 1s 395ms/step
# Epoch>2, Batch262/390, d1=0.614, d2=0.705 g=0.762
# 2/2 [==============================] - 1s 388ms/step
# Epoch>2, Batch263/390, d1=0.581, d2=0.705 g=0.748
# 2/2 [==============================] - 1s 374ms/step
# Epoch>2, Batch264/390, d1=0.590, d2=0.740 g=0.765
# 2/2 [==============================] - 1s 393ms/step
# Epoch>2, Batch265/390, d1=0.633, d2=0.717 g=0.749
# 2/2 [==============================] - 1s 406ms/step
# Epoch>2, Batch266/390, d1=0.613, d2=0.735 g=0.764
# 2/2 [==============================] - 1s 381ms/step
# Epoch>2, Batch267/390, d1=0.628, d2=0.735 g=0.765
# 2/2 [==============================] - 1s 402ms/step
# Epoch>2, Batch268/390, d1=0.609, d2=0.723 g=0.767
# 2/2 [==============================] - 1s 390ms/step
# Epoch>2, Batch269/390, d1=0.626, d2=0.720 g=0.786
# 2/2 [==============================] - 1s 396ms/step
# Epoch>2, Batch270/390, d1=0.604, d2=0.640 g=0.804
# 2/2 [==============================] - 1s 712ms/step
# Epoch>2, Batch271/390, d1=0.695, d2=0.691 g=0.801
# 2/2 [==============================] - 1s 734ms/step
# Epoch>2, Batch272/390, d1=0.586, d2=0.707 g=0.783
# 2/2 [==============================] - 1s 730ms/step
# Epoch>2, Batch273/390, d1=0.656, d2=0.725 g=0.796
# 2/2 [==============================] - 1s 468ms/step
# Epoch>2, Batch274/390, d1=0.665, d2=0.758 g=0.775
# 2/2 [==============================] - 1s 585ms/step
# Epoch>2, Batch275/390, d1=0.728, d2=0.745 g=0.799
# 2/2 [==============================] - 1s 695ms/step
# Epoch>2, Batch276/390, d1=0.701, d2=0.714 g=0.781
# 2/2 [==============================] - 1s 496ms/step
# Epoch>2, Batch277/390, d1=0.683, d2=0.696 g=0.787
# 2/2 [==============================] - 1s 691ms/step
# Epoch>2, Batch278/390, d1=0.730, d2=0.658 g=0.838
# 2/2 [==============================] - 1s 402ms/step
# Epoch>2, Batch279/390, d1=0.691, d2=0.679 g=0.832
# 2/2 [==============================] - 1s 384ms/step
# Epoch>2, Batch280/390, d1=0.749, d2=0.645 g=0.864
# 2/2 [==============================] - 1s 401ms/step
# Epoch>2, Batch281/390, d1=0.715, d2=0.627 g=0.904
# 2/2 [==============================] - 1s 410ms/step
# Epoch>2, Batch282/390, d1=0.713, d2=0.590 g=0.934
# 2/2 [==============================] - 1s 389ms/step
# Epoch>2, Batch283/390, d1=0.711, d2=0.594 g=0.900
# 2/2 [==============================] - 1s 389ms/step
# Epoch>2, Batch284/390, d1=0.714, d2=0.584 g=0.927
# 2/2 [==============================] - 1s 388ms/step
# Epoch>2, Batch285/390, d1=0.758, d2=0.597 g=0.900
# 2/2 [==============================] - 1s 387ms/step
# Epoch>2, Batch286/390, d1=0.710, d2=0.611 g=0.895
# 2/2 [==============================] - 1s 388ms/step
# Epoch>2, Batch287/390, d1=0.761, d2=0.615 g=0.836
# 2/2 [==============================] - 1s 377ms/step
# Epoch>2, Batch288/390, d1=0.695, d2=0.656 g=0.846
# 2/2 [==============================] - 1s 404ms/step
# Epoch>2, Batch289/390, d1=0.674, d2=0.683 g=0.783
# 2/2 [==============================] - 1s 385ms/step
# Epoch>2, Batch290/390, d1=0.698, d2=0.724 g=0.753
# 2/2 [==============================] - 1s 389ms/step
# Epoch>2, Batch291/390, d1=0.635, d2=0.787 g=0.693
# 2/2 [==============================] - 1s 385ms/step
# Epoch>2, Batch292/390, d1=0.651, d2=0.795 g=0.688
# 2/2 [==============================] - 1s 415ms/step
# Epoch>2, Batch293/390, d1=0.707, d2=0.840 g=0.673
# 2/2 [==============================] - 1s 399ms/step
# Epoch>2, Batch294/390, d1=0.664, d2=0.843 g=0.649
# 2/2 [==============================] - 1s 383ms/step
# Epoch>2, Batch295/390, d1=0.666, d2=0.911 g=0.644
# 2/2 [==============================] - 1s 387ms/step
# Epoch>2, Batch296/390, d1=0.692, d2=0.828 g=0.636
# 2/2 [==============================] - 1s 379ms/step
# Epoch>2, Batch297/390, d1=0.699, d2=0.865 g=0.657
# 2/2 [==============================] - 1s 413ms/step
# Epoch>2, Batch298/390, d1=0.689, d2=0.820 g=0.662
# 2/2 [==============================] - 1s 402ms/step
# Epoch>2, Batch299/390, d1=0.690, d2=0.773 g=0.718
# 2/2 [==============================] - 1s 386ms/step
# Epoch>2, Batch300/390, d1=0.739, d2=0.734 g=0.760
# 2/2 [==============================] - 1s 399ms/step
# Epoch>2, Batch301/390, d1=0.733, d2=0.709 g=0.802
# 2/2 [==============================] - 1s 416ms/step
# Epoch>2, Batch302/390, d1=0.718, d2=0.648 g=0.889
# 2/2 [==============================] - 1s 375ms/step
# Epoch>2, Batch303/390, d1=0.686, d2=0.593 g=0.952
# 2/2 [==============================] - 1s 412ms/step
# Epoch>2, Batch304/390, d1=0.680, d2=0.539 g=1.010
# 2/2 [==============================] - 1s 400ms/step
# Epoch>2, Batch305/390, d1=0.654, d2=0.499 g=1.072
# 2/2 [==============================] - 1s 385ms/step
# Epoch>2, Batch306/390, d1=0.583, d2=0.445 g=1.193
# 2/2 [==============================] - 1s 387ms/step
# Epoch>2, Batch307/390, d1=0.573, d2=0.444 g=1.193
# 2/2 [==============================] - 1s 377ms/step
# Epoch>2, Batch308/390, d1=0.559, d2=0.484 g=1.148
# 2/2 [==============================] - 1s 396ms/step
# Epoch>2, Batch309/390, d1=0.572, d2=0.536 g=1.030
# 2/2 [==============================] - 1s 408ms/step
# Epoch>2, Batch310/390, d1=0.478, d2=0.610 g=0.956
# 2/2 [==============================] - 1s 409ms/step
# Epoch>2, Batch311/390, d1=0.526, d2=0.737 g=0.821
# 2/2 [==============================] - 1s 378ms/step
# Epoch>2, Batch312/390, d1=0.605, d2=0.852 g=0.693
# 2/2 [==============================] - 1s 379ms/step
# Epoch>2, Batch313/390, d1=0.580, d2=0.902 g=0.723
# 2/2 [==============================] - 1s 397ms/step
# Epoch>2, Batch314/390, d1=0.663, d2=0.897 g=0.827
# 2/2 [==============================] - 1s 520ms/step
# Epoch>2, Batch315/390, d1=0.668, d2=0.762 g=0.879
# 2/2 [==============================] - 1s 720ms/step
# Epoch>2, Batch316/390, d1=0.702, d2=0.687 g=1.032
# 2/2 [==============================] - 1s 397ms/step
# Epoch>2, Batch317/390, d1=0.780, d2=0.612 g=1.067
# 2/2 [==============================] - 1s 409ms/step
# Epoch>2, Batch318/390, d1=0.713, d2=0.563 g=1.154
# 2/2 [==============================] - 1s 406ms/step
# Epoch>2, Batch319/390, d1=0.737, d2=0.438 g=1.297
# 2/2 [==============================] - 1s 388ms/step
# Epoch>2, Batch320/390, d1=0.758, d2=0.421 g=1.325
# 2/2 [==============================] - 1s 440ms/step
# Epoch>2, Batch321/390, d1=0.749, d2=0.403 g=1.349
# 2/2 [==============================] - 1s 579ms/step
# Epoch>2, Batch322/390, d1=0.770, d2=0.390 g=1.331
# 2/2 [==============================] - 1s 627ms/step
# Epoch>2, Batch323/390, d1=0.684, d2=0.423 g=1.288
# 2/2 [==============================] - 1s 401ms/step
# Epoch>2, Batch324/390, d1=0.717, d2=0.458 g=1.133
# 2/2 [==============================] - 1s 383ms/step
# Epoch>2, Batch325/390, d1=0.608, d2=0.496 g=0.985
# 2/2 [==============================] - 1s 390ms/step
# Epoch>2, Batch326/390, d1=0.673, d2=0.589 g=0.902
# 2/2 [==============================] - 1s 474ms/step
# Epoch>2, Batch327/390, d1=0.696, d2=0.661 g=0.790
# 2/2 [==============================] - 1s 453ms/step
# Epoch>2, Batch328/390, d1=0.724, d2=0.819 g=0.708
# 2/2 [==============================] - 1s 537ms/step
# Epoch>2, Batch329/390, d1=0.653, d2=0.816 g=0.668
# 2/2 [==============================] - 1s 684ms/step
# Epoch>2, Batch330/390, d1=0.747, d2=0.869 g=0.626
# 2/2 [==============================] - 1s 380ms/step
# Epoch>2, Batch331/390, d1=0.665, d2=0.916 g=0.600
# 2/2 [==============================] - 1s 400ms/step
# Epoch>2, Batch332/390, d1=0.659, d2=0.857 g=0.643
# 2/2 [==============================] - 1s 384ms/step
# Epoch>2, Batch333/390, d1=0.691, d2=0.871 g=0.635
# 2/2 [==============================] - 1s 393ms/step
# Epoch>2, Batch334/390, d1=0.709, d2=0.820 g=0.654
# 2/2 [==============================] - 1s 431ms/step
# Epoch>2, Batch335/390, d1=0.684, d2=0.807 g=0.690
# 2/2 [==============================] - 1s 541ms/step
# Epoch>2, Batch336/390, d1=0.752, d2=0.791 g=0.712
# 2/2 [==============================] - 1s 630ms/step
# Epoch>2, Batch337/390, d1=0.745, d2=0.737 g=0.744
# 2/2 [==============================] - 1s 642ms/step
# Epoch>2, Batch338/390, d1=0.826, d2=0.785 g=0.731
# 2/2 [==============================] - 1s 413ms/step
# Epoch>2, Batch339/390, d1=0.759, d2=0.747 g=0.747
# 2/2 [==============================] - 1s 383ms/step
# Epoch>2, Batch340/390, d1=0.755, d2=0.745 g=0.760
# 2/2 [==============================] - 1s 408ms/step
# Epoch>2, Batch341/390, d1=0.726, d2=0.688 g=0.775
# 2/2 [==============================] - 1s 382ms/step
# Epoch>2, Batch342/390, d1=0.748, d2=0.691 g=0.785
# 2/2 [==============================] - 1s 398ms/step
# Epoch>2, Batch343/390, d1=0.741, d2=0.684 g=0.813
# 2/2 [==============================] - 1s 406ms/step
# Epoch>2, Batch344/390, d1=0.729, d2=0.669 g=0.796
# 2/2 [==============================] - 1s 402ms/step
# Epoch>2, Batch345/390, d1=0.743, d2=0.655 g=0.867
# 2/2 [==============================] - 1s 383ms/step
# Epoch>2, Batch346/390, d1=0.734, d2=0.644 g=0.831
# 2/2 [==============================] - 1s 386ms/step
# Epoch>2, Batch347/390, d1=0.758, d2=0.653 g=0.859
# 2/2 [==============================] - 1s 380ms/step
# Epoch>2, Batch348/390, d1=0.726, d2=0.604 g=0.869
# 2/2 [==============================] - 1s 380ms/step
# Epoch>2, Batch349/390, d1=0.703, d2=0.613 g=0.829
# 2/2 [==============================] - 1s 402ms/step
# Epoch>2, Batch350/390, d1=0.669, d2=0.598 g=0.857
# 2/2 [==============================] - 1s 380ms/step
# Epoch>2, Batch351/390, d1=0.685, d2=0.636 g=0.865
# 2/2 [==============================] - 1s 377ms/step
# Epoch>2, Batch352/390, d1=0.743, d2=0.627 g=0.835
# 2/2 [==============================] - 1s 395ms/step
# Epoch>2, Batch353/390, d1=0.680, d2=0.649 g=0.818
# 2/2 [==============================] - 1s 399ms/step
# Epoch>2, Batch354/390, d1=0.688, d2=0.631 g=0.843
# 2/2 [==============================] - 1s 387ms/step
# Epoch>2, Batch355/390, d1=0.632, d2=0.635 g=0.841
# 2/2 [==============================] - 1s 402ms/step
# Epoch>2, Batch356/390, d1=0.670, d2=0.648 g=0.844
# 2/2 [==============================] - 1s 383ms/step
# Epoch>2, Batch357/390, d1=0.662, d2=0.624 g=0.815
# 2/2 [==============================] - 1s 384ms/step
# Epoch>2, Batch358/390, d1=0.616, d2=0.629 g=0.805
# 2/2 [==============================] - 1s 405ms/step
# Epoch>2, Batch359/390, d1=0.625, d2=0.652 g=0.800
# 2/2 [==============================] - 1s 402ms/step
# Epoch>2, Batch360/390, d1=0.648, d2=0.687 g=0.831
# 2/2 [==============================] - 1s 381ms/step
# Epoch>2, Batch361/390, d1=0.644, d2=0.643 g=0.832
# 2/2 [==============================] - 1s 386ms/step
# Epoch>2, Batch362/390, d1=0.634, d2=0.709 g=0.814
# 2/2 [==============================] - 1s 389ms/step
# Epoch>2, Batch363/390, d1=0.631, d2=0.649 g=0.793
# 2/2 [==============================] - 1s 386ms/step
# Epoch>2, Batch364/390, d1=0.652, d2=0.662 g=0.827
# 2/2 [==============================] - 1s 391ms/step
# Epoch>2, Batch365/390, d1=0.619, d2=0.647 g=0.817
# 2/2 [==============================] - 1s 393ms/step
# Epoch>2, Batch366/390, d1=0.625, d2=0.657 g=0.794
# 2/2 [==============================] - 1s 413ms/step
# Epoch>2, Batch367/390, d1=0.634, d2=0.620 g=0.814
# 2/2 [==============================] - 1s 383ms/step
# Epoch>2, Batch368/390, d1=0.620, d2=0.609 g=0.873
# 2/2 [==============================] - 1s 404ms/step
# Epoch>2, Batch369/390, d1=0.608, d2=0.596 g=0.912
# 2/2 [==============================] - 1s 378ms/step
# Epoch>2, Batch370/390, d1=0.594, d2=0.579 g=0.938
# 2/2 [==============================] - 1s 402ms/step
# Epoch>2, Batch371/390, d1=0.620, d2=0.569 g=0.920
# 2/2 [==============================] - 1s 388ms/step
# Epoch>2, Batch372/390, d1=0.591, d2=0.545 g=0.929
# 2/2 [==============================] - 1s 399ms/step
# Epoch>2, Batch373/390, d1=0.578, d2=0.551 g=0.974
# 2/2 [==============================] - 1s 391ms/step
# Epoch>2, Batch374/390, d1=0.593, d2=0.519 g=0.945
# 2/2 [==============================] - 1s 414ms/step
# Epoch>2, Batch375/390, d1=0.606, d2=0.553 g=0.958
# 2/2 [==============================] - 1s 389ms/step
# Epoch>2, Batch376/390, d1=0.551, d2=0.562 g=0.933
# 2/2 [==============================] - 1s 408ms/step
# Epoch>2, Batch377/390, d1=0.549, d2=0.556 g=0.923
# 2/2 [==============================] - 1s 380ms/step
# Epoch>2, Batch378/390, d1=0.560, d2=0.554 g=0.908
# 2/2 [==============================] - 1s 390ms/step
# Epoch>2, Batch379/390, d1=0.590, d2=0.614 g=0.869
# 2/2 [==============================] - 1s 387ms/step
# Epoch>2, Batch380/390, d1=0.582, d2=0.647 g=0.864
# 2/2 [==============================] - 1s 379ms/step
# Epoch>2, Batch381/390, d1=0.520, d2=0.646 g=0.795
# 2/2 [==============================] - 1s 398ms/step
# Epoch>2, Batch382/390, d1=0.504, d2=0.659 g=0.751
# 2/2 [==============================] - 1s 381ms/step
# Epoch>2, Batch383/390, d1=0.537, d2=0.693 g=0.755
# 2/2 [==============================] - 1s 374ms/step
# Epoch>2, Batch384/390, d1=0.546, d2=0.730 g=0.725
# 2/2 [==============================] - 1s 379ms/step
# Epoch>2, Batch385/390, d1=0.548, d2=0.754 g=0.712
# 2/2 [==============================] - 1s 395ms/step
# Epoch>2, Batch386/390, d1=0.496, d2=0.759 g=0.712
# 2/2 [==============================] - 1s 422ms/step
# Epoch>2, Batch387/390, d1=0.483, d2=0.748 g=0.712
# 2/2 [==============================] - 1s 385ms/step
# Epoch>2, Batch388/390, d1=0.505, d2=0.743 g=0.714
# 2/2 [==============================] - 1s 382ms/step
# Epoch>2, Batch389/390, d1=0.505, d2=0.745 g=0.713
# 2/2 [==============================] - 1s 390ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch>2, Batch390/390, d1=0.525, d2=0.737 g=0.757

# %%
##########################################################
# Now, let us load the generator model and generate images
# Lod the trained model and generate a few images
from numpy import asarray
from numpy.random import randn
from numpy.random import randint
from keras.models import load_model
import numpy as np
#

# %%
#Note: CIFAR10 classes are: airplane, automobile, bird, cat, deer, dog, frog, horse,
# ship, truck

# load model
model = load_model('/content/cifar_conditional_generator_25epochs.h5')

# generate multiple images

latent_points, labels = generate_latent_points(100, 100)
# specify labels - generate 10 sets of labels each gping from 0 to 9
labels = asarray([x for _ in range(10) for x in range(10)])
# generate images
X  = model.predict([latent_points, labels])
# scale from [-1,1] to [0,1]
X = (X + 1) / 2.0
X = (X*255).astype(np.uint8)
# plot the result (10 sets of images, all images in a column should be of same class in the plot)
# Plot generated images
def show_plot(examples, n):
	for i in range(n * n):
		plt.subplot(n, n, 1 + i)
		plt.axis('off')
		plt.imshow(examples[i, :, :, :])
	plt.show()

show_plot(X, 10)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 4/4 [==============================] - 4s 697ms/step
